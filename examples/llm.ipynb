# %%
from langchain.agents import create_sql_agent
from langchain.agents.agent_types import AgentType
from langchain_openai import OpenAI
from langchain_core.prompts import PromptTemplate
from langchain.sql_database import SQLDatabase
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit

uri = 'duckdb:///../rentradar/db/rentradar.db'

# %% [markdown]
# ## Setup LangChain

# %%
db = SQLDatabase.from_uri(
    uri,
    sample_rows_in_table_info=3
)

print(db.table_info)
# Out:
# CREATE TABLE counties (
# 	id VARCHAR,
# 	county VARCHAR
# )
#
# /*
# 3 rows from counties table:
# id	county
# cd1120ac-f345-5b53-baab-74449599067b	Albemarle County
# 52c07453-ee28-5c0d-978d-d403c78b58af	Charlottesville City
# 84328055-b1cf-5279-a09a-e98f63e3d09b	Louisa County
# */
#
#
# CREATE TABLE current_market_stats (
# 	bedrooms INTEGER,
# 	"averageRent" INTEGER,
# 	"minRent" INTEGER,
# 	"maxRent" INTEGER,
# 	"totalListings" INTEGER,
# 	"lastUpdatedDate" VARCHAR,
# 	"zipCode" INTEGER
# )
#
# /*
# 3 rows from current_market_stats table:
# bedrooms	averageRent	minRent	maxRent	totalListings	lastUpdatedDate	zipCode
# 1	1439	610	3000	35	2024-02-24T00:00:00.000Z	22903
# 2	1734	875	2850	60	2024-02-24T00:00:00.000Z	22903
# 3	2260	1425	4000	46	2024-02-24T00:00:00.000Z	22903
# */
#
#
# CREATE TABLE historic_market_stats (
# 	bedrooms INTEGER,
# 	"averageRent" REAL,
# 	"minRent" INTEGER,
# 	"maxRent" INTEGER,
# 	"totalListings" INTEGER,
# 	date VARCHAR,
# 	"zipCode" INTEGER
# )
#
# /*
# 3 rows from historic_market_stats table:
# bedrooms	averageRent	minRent	maxRent	totalListings	date	zipCode
# 0	916.6699829101562	515	1299	3	2021-03	22903
# 1	1148.3299560546875	600	1560	12	2021-03	22903
# 2	1653.699951171875	950	4000	10	2021-03	22903
# */
#
#
# CREATE TABLE long_term_rentals (
# 	property_id VARCHAR,
# 	id VARCHAR,
# 	price INTEGER,
# 	status VARCHAR,
# 	"daysOnMarket" REAL,
# 	"listedDate" VARCHAR,
# 	"createdDate" VARCHAR,
# 	"lastSeenDate" VARCHAR,
# 	"removedDate" VARCHAR
# )
#
# /*
# 3 rows from long_term_rentals table:
# property_id	id	price	status	daysOnMarket	listedDate	createdDate	lastSeenDate	removedDate
# 36b8783f-79ec-544a-9b0d-85ed6ded8ebd	1050-Druid-Ave,-Charlottesville,-VA-22902	1600	Active	5.0	2024-02-20T00:00:00.000Z	2019-09-17T01:39:08.267Z	2024-02-24T00:00:00.000Z	None
# 130b5c8c-c2d9-5000-a5bb-be8b42624167	1212-Cedars-Ct,-Charlottesville,-VA-22903	1399	Active	365.0	2023-02-25T00:00:00.000Z	2019-11-07T05:01:39.369Z	2024-02-24T00:00:00.000Z	None
# 9705280c-76a8-5d31-bfaf-b474994ff218	125-Longwood-Dr,---A,-Charlottesville,-VA-22903	1425	Active	365.0	2023-02-25T00:00:00.000Z	2019-04-26T14:22:58.384Z	2024-02-24T00:00:00.000Z	None
# */
#
#
# CREATE TABLE properties (
# 	property_id VARCHAR,
# 	id VARCHAR,
# 	"formattedAddress" VARCHAR,
# 	"zipCode" INTEGER,
# 	county VARCHAR,
# 	subdivision VARCHAR,
# 	latitude REAL,
# 	longitude REAL,
# 	"propertyType" VARCHAR,
# 	"ownerOccupied" INTEGER,
# 	"yearBuilt" REAL,
# 	"lastSaleDate" VARCHAR,
# 	"lastSalePrice" REAL,
# 	zoning VARCHAR,
# 	"assessorID" VARCHAR,
# 	"legalDescription" VARCHAR
# )
#
# /*
# 3 rows from properties table:
# property_id	id	formattedAddress	zipCode	county	subdivision	latitude	longitude	propertyType	ownerOccupied	yearBuilt	lastSaleDate	lastSalePrice	zoning	assessorID	legalDescription
# c6b549be-e4e4-56db-8a92-1d7f12fb7172	4580-Lambeth,-Charlottesville,-VA-22904	4580 Lambeth, Charlottesville, VA 22904	22904	Albemarle	None	38.04106140136719	-78.50210571289062	None	None	None	None	None	None	None	None
# 37f12acf-ee26-5199-960f-f910b90b4d08	4545-Lambeth,-Charlottesville,-VA-22904	4545 Lambeth, Charlottesville, VA 22904	22904	Albemarle	None	38.04106140136719	-78.50210571289062	None	None	None	None	None	None	None	None
# f124568d-8218-5724-9031-35d34b0fe49a	4501-Lambeth,-Charlottesville,-VA-22904	4501 Lambeth, Charlottesville, VA 22904	22904	Albemarle	None	38.04106140136719	-78.50210571289062	None	None	None	None	None	None	None	None
# */
#
#
# CREATE TABLE property_features (
# 	property_id VARCHAR,
# 	bedrooms REAL,
# 	bathrooms REAL,
# 	"squareFootage" REAL,
# 	"lotSize" REAL,
# 	"floorCount" REAL,
# 	garage INTEGER,
# 	"garageType" VARCHAR,
# 	"architectureType" VARCHAR,
# 	"exteriorType" VARCHAR,
# 	heating INTEGER,
# 	"heatingType" VARCHAR,
# 	cooling INTEGER,
# 	"coolingType" VARCHAR,
# 	"unitCount" REAL,
# 	"garageSpaces" REAL,
# 	"roofType" VARCHAR,
# 	"foundationType" VARCHAR,
# 	"roomCount" REAL,
# 	fireplace INTEGER,
# 	"fireplaceType" VARCHAR,
# 	pool INTEGER,
# 	"poolType" VARCHAR,
# 	"viewType" VARCHAR
# )
#
# /*
# 3 rows from property_features table:
# property_id	bedrooms	bathrooms	squareFootage	lotSize	floorCount	garage	garageType	architectureType	exteriorType	heating	heatingType	cooling	coolingType	unitCount	garageSpaces	roofType	foundationType	roomCount	fireplace	fireplaceType	pool	poolType	viewType
# 0002939e-49d9-5578-b0fd-2bdac3057bae	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# 00075623-f6c9-54ba-a326-367830d9d027	None	1.0	722.0	None	2.0	None	None	Townhouse	Brick	1	Heat Pump	1	Central	1.0	None	Composition Shingle	None	6.0	1	Prefab	None	None	None
# 00098105-7a85-5d19-9dc5-630ba94b6a4f	3.0	4.0	4228.0	206474.0	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# */
#
#
# CREATE TABLE property_owners (
# 	owner_id VARCHAR,
# 	property_id VARCHAR,
# 	owner VARCHAR
# )
#
# /*
# 3 rows from property_owners table:
# owner_id	property_id	owner
# 548214dc-a57a-5937-8255-a22348e7eb3e	be793931-39ee-5c0c-803b-bde70a082871	CHARLOTTESVILLE INVESTMENT PROPERTI
# 38a0b4d7-c999-543c-a788-fa5b651f2750	f4983b4c-3991-569f-8291-73134d413851	RAIA 5TH STREET WOODBURY TIC LLC
# 5fccf1eb-86f9-566e-a2fb-5d3e98ba3d16	109dbee5-149b-5856-b87e-1e7961a423a9	AVEMORE ASSOCIATES LP
# */
#
#
# CREATE TABLE property_taxes (
# 	property_tax_id VARCHAR,
# 	property_id VARCHAR,
# 	year VARCHAR,
# 	total INTEGER
# )
#
# /*
# 3 rows from property_taxes table:
# property_tax_id	property_id	year	total
# a9a2b0c2-f9d0-5bff-a416-d15d06c1bac3	be793931-39ee-5c0c-803b-bde70a082871	2022	2403
# a55ab43f-4ae0-5fb2-ad31-2e3b919b267f	f4983b4c-3991-569f-8291-73134d413851	2019	366281
# 0b109fe6-1048-5806-a71b-18c91b9f9e7f	109dbee5-149b-5856-b87e-1e7961a423a9	2021	435435
# */
#
#
# CREATE TABLE property_types (
# 	id VARCHAR,
# 	"propertyType" VARCHAR,
# 	description VARCHAR
# )
#
# /*
# 3 rows from property_types table:
# id	propertyType	description
# 696f487f-8604-52ae-b450-2e9fe9075f34	Apartment	A commercial multi-family building or apartment complex (5+ units)
# e6bd4a8e-d5c3-55ec-8b15-d64daedbb5f2	Condo	A single unit in a condominium development or building, which is part of a homeowner’s association (
# 1adb7637-5e3e-5de1-8206-6a5b698af656	Multi-Family	A residential multi-family building (2-4 units)
# */
#
#
# CREATE TABLE sale_listings (
# 	property_id VARCHAR,
# 	id VARCHAR,
# 	status VARCHAR,
# 	price INTEGER,
# 	"listedDate" VARCHAR,
# 	"removedDate" VARCHAR,
# 	"createdDate" VARCHAR,
# 	"lastSeenDate" VARCHAR,
# 	"daysOnMarket" INTEGER
# )
#
# /*
# 3 rows from sale_listings table:
# property_id	id	status	price	listedDate	removedDate	createdDate	lastSeenDate	daysOnMarket
# 4ded1a86-f94b-55bc-8601-87a6682a32cf	1265-Pounding-Creek-Rd,-Charlottesville,-VA-22903	Active	545000	2024-02-07T00:00:00.000Z	None	2020-09-15T11:05:31.677Z	2024-02-24T00:00:00.000Z	18
# 0eb49cdf-93ff-59d6-9b4e-033e2425722a	2940-Daventry-Ln,-Charlottesville,-VA-22911	Active	1500000	2024-02-06T00:00:00.000Z	None	2020-09-20T15:09:51.132Z	2024-02-24T00:00:00.000Z	19
# 0376d46a-299f-535c-8e26-57f8943009ba	2621-Coopers-Ln,-Charlottesville,-VA-22902	Active	2995000	2024-01-20T00:00:00.000Z	None	2020-09-23T14:10:43.630Z	2024-02-24T00:00:00.000Z	36
# */
#
#
# CREATE TABLE tax_assessments (
# 	assessment_id VARCHAR,
# 	property_id VARCHAR,
# 	year VARCHAR,
# 	total_value REAL,
# 	land_value REAL,
# 	improvements_value REAL
# )
#
# /*
# 3 rows from tax_assessments table:
# assessment_id	property_id	year	total_value	land_value	improvements_value
# 98d21fd0-bde0-5880-99fd-d5c57c0553fa	be793931-39ee-5c0c-803b-bde70a082871	2023	281400.0	281300.0	100.0
# 283a33f7-b245-507e-9d8b-16e6da32a55d	f4983b4c-3991-569f-8291-73134d413851	2020	44053100.0	4400000.0	39653100.0
# c5cd6269-3b51-5d32-808c-21a0740cc912	109dbee5-149b-5856-b87e-1e7961a423a9	2022	57136000.0	4480000.0	52656000.0
# */
# /home/timboslice/.cache/pypoetry/virtualenvs/rentradar-ZiKOXBpo-py3.10/lib/python3.10/site-packages/duckdb_engine/__init__.py:181: DuckDBEngineWarning: duckdb-engine doesn't yet support reflection on indices
#   warnings.warn(

# %%
toolkit = SQLDatabaseToolkit(
    db=db, 
    llm=OpenAI(temperature=0)
)

# %%
agent_executor = create_sql_agent(
    llm=OpenAI(temperature=0),
    toolkit=toolkit,
    verbose=True,
    agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION
)

# %%
template = """/
You are a SQL analyst that is querying a database of real estate data. The database has the following tables:

1. **counties**: Stores the identifiers and names of counties.
   - `id`: Unique identifier for each county.
   - `county`: Name of the county.

2. **current_market_stats**: Contains current rental market statistics by zip code.
   - `bedrooms`: Number of bedrooms.
   - `averageRent`: Average rental price.
   - `minRent`: Minimum rental price.
   - `maxRent`: Maximum rental price.
   - `totalListings`: Total number of rental listings.
   - `lastUpdatedDate`: Date when the data was last updated.
   - `zipCode`: Zip code of the rental property.

3. **historic_market_stats**: Holds historical rental market data collected over time by zip code.
   - `bedrooms`: Number of bedrooms.
   - `averageRent`: Historical average rental price.
   - `minRent`: Historical minimum rental price.
   - `maxRent`: Historical maximum rental price.
   - `totalListings`: Historical number of rental listings.
   - `date`: Date of the recorded data.
   - `zipCode`: Zip code of the rental property.

4. **long_term_rentals**: Details long-term rental listings.
   - `property_id`: Unique identifier for the property.
   - `id`: Unique identifier for the listing.
   - `price`: Rental price.
   - `status`: Current status of the listing.
   - `daysOnMarket`: Number of days the property has been on the market.
   - `listedDate`, `createdDate`, `lastSeenDate`, `removedDate`: Relevant dates regarding the property's listing status.

5. **properties**: General information about properties.
   - `property_id`: Unique identifier for the property.
   - `id`: Unique identifier for the record.
   - `formattedAddress`: Full address of the property.
   - `zipCode`: Zip code of the property.
   - `county`: County where the property is located.
   - `subdivision`: Subdivision of the property.
   - `latitude`, `longitude`: Geographical coordinates of the property.
   - `propertyType`: Type of the property (e.g., residential, commercial).
   - `ownerOccupied`: Indicates if the property is owner-occupied.
   - `yearBuilt`: Year the property was built.
   - `lastSaleDate`, `lastSalePrice`: Most recent sale date and price.
   - `zoning`: Zoning classification of the property.
   - `assessorID`, `legalDescription`: Assessor's identification and legal description of the property.

6. **property_features**: Specific features of properties.
   - `property_id`: Unique identifier for the property.
   - `bedrooms`, `bathrooms`: Number of bedrooms and bathrooms.
   - `squareFootage`: Total square footage of the property.
   - `lotSize`: Size of the property's lot.
   - `floorCount`: Number of floors in the property.
   - `garage`, `garageType`: Indicates if there is a garage and its type.
   - `architectureType`, `exteriorType`: Architectural and exterior material type.
   - `heating`, `heatingType`, `cooling`, `coolingType`: Heating and cooling systems and their types.
   - `unitCount`, `garageSpaces`: Number of units and garage spaces.
   - `roofType`, `foundationType`: Type of roof and foundation.
   - `roomCount`: Number of rooms.
   - `fireplace`, `fireplaceType`: Indicates presence of a fireplace and its type.
   - `pool`, `poolType`, `viewType`: Presence of a pool, its type, and view type.

7. **property_owners**: Information about property owners.
   - `owner_id`: Unique identifier for the owner.
   - `property_id`: Unique identifier for the property.
   - `owner`: Name of the property owner.

8. **property_taxes**: Property tax records.
   - `property_tax_id`: Unique identifier for the tax record.
   - `property_id`: Unique identifier for the property.
   - `year`: Tax year.
   - `total`: Total amount of property tax.

9. **property_types**: Descriptions of different property types.
   - `id`: Unique identifier for the property type.
   - `propertyType`: Type of property.
   - `description`: Description of the property type.

10. **sale_listings**: Details about properties listed for sale.
    - `property_id`: Unique identifier for the property.
    - `id`: Unique identifier for the listing.
    - `status`: Current status of the listing (e.g., active, sold).
    - `price`: Listing price.
    - `listedDate`, `removedDate`, `createdDate`, `lastSeenDate`, `daysOnMarket`: Relevant dates and duration on market for the listing.

11. **tax_assessments**: Valuation assessments for tax purposes.
    - `assessment_id`: Unique identifier for the assessment.
    - `property_id`: Unique identifier for the property.
    - `year`: Year of the assessment.
    - `total_value`, `land_value`, `improvements_value`: Total, land, and improvements valuation.

Your job is to write and execute a query that answers the following question:
{query}
"""

prompt = PromptTemplate.from_template(template)

# %%
agent_executor.invoke(
    prompt.format(
        query = "What is the address of the property that paid the most property taxes in 2023?"
    )
)
# Out:
# > Entering new SQL Agent Executor chain...
#  I need to find the property with the highest property tax payment in 2023.
# Action: sql_db_query
# Action Input: SELECT formattedAddress FROM properties
#             JOIN property_taxes ON properties.property_id = property_taxes.property_id
#             WHERE year = 2023
#             ORDER BY total DESC
#             LIMIT 1[('1215 Silverbell Ter, Charlottesville, VA 22903',)]1215 Silverbell Ter, Charlottesville, VA 22903 is the address of the property with the highest property tax payment in 2023.
# Final Answer: 1215 Silverbell Ter, Charlottesville, VA 22903
#
# > Finished chain.
# {'input': "/\nYou are a SQL analyst that is querying a database of real estate data. The database has the following tables:\n\n1. **counties**: Stores the identifiers and names of counties.\n   - `id`: Unique identifier for each county.\n   - `county`: Name of the county.\n\n2. **current_market_stats**: Contains current rental market statistics by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Average rental price.\n   - `minRent`: Minimum rental price.\n   - `maxRent`: Maximum rental price.\n   - `totalListings`: Total number of rental listings.\n   - `lastUpdatedDate`: Date when the data was last updated.\n   - `zipCode`: Zip code of the rental property.\n\n3. **historic_market_stats**: Holds historical rental market data collected over time by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Historical average rental price.\n   - `minRent`: Historical minimum rental price.\n   - `maxRent`: Historical maximum rental price.\n   - `totalListings`: Historical number of rental listings.\n   - `date`: Date of the recorded data.\n   - `zipCode`: Zip code of the rental property.\n\n4. **long_term_rentals**: Details long-term rental listings.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the listing.\n   - `price`: Rental price.\n   - `status`: Current status of the listing.\n   - `daysOnMarket`: Number of days the property has been on the market.\n   - `listedDate`, `createdDate`, `lastSeenDate`, `removedDate`: Relevant dates regarding the property's listing status.\n\n5. **properties**: General information about properties.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the record.\n   - `formattedAddress`: Full address of the property.\n   - `zipCode`: Zip code of the property.\n   - `county`: County where the property is located.\n   - `subdivision`: Subdivision of the property.\n   - `latitude`, `longitude`: Geographical coordinates of the property.\n   - `propertyType`: Type of the property (e.g., residential, commercial).\n   - `ownerOccupied`: Indicates if the property is owner-occupied.\n   - `yearBuilt`: Year the property was built.\n   - `lastSaleDate`, `lastSalePrice`: Most recent sale date and price.\n   - `zoning`: Zoning classification of the property.\n   - `assessorID`, `legalDescription`: Assessor's identification and legal description of the property.\n\n6. **property_features**: Specific features of properties.\n   - `property_id`: Unique identifier for the property.\n   - `bedrooms`, `bathrooms`: Number of bedrooms and bathrooms.\n   - `squareFootage`: Total square footage of the property.\n   - `lotSize`: Size of the property's lot.\n   - `floorCount`: Number of floors in the property.\n   - `garage`, `garageType`: Indicates if there is a garage and its type.\n   - `architectureType`, `exteriorType`: Architectural and exterior material type.\n   - `heating`, `heatingType`, `cooling`, `coolingType`: Heating and cooling systems and their types.\n   - `unitCount`, `garageSpaces`: Number of units and garage spaces.\n   - `roofType`, `foundationType`: Type of roof and foundation.\n   - `roomCount`: Number of rooms.\n   - `fireplace`, `fireplaceType`: Indicates presence of a fireplace and its type.\n   - `pool`, `poolType`, `viewType`: Presence of a pool, its type, and view type.\n\n7. **property_owners**: Information about property owners.\n   - `owner_id`: Unique identifier for the owner.\n   - `property_id`: Unique identifier for the property.\n   - `owner`: Name of the property owner.\n\n8. **property_taxes**: Property tax records.\n   - `property_tax_id`: Unique identifier for the tax record.\n   - `property_id`: Unique identifier for the property.\n   - `year`: Tax year.\n   - `total`: Total amount of property tax.\n\n9. **property_types**: Descriptions of different property types.\n   - `id`: Unique identifier for the property type.\n   - `propertyType`: Type of property.\n   - `de ...
#  'output': '1215 Silverbell Ter, Charlottesville, VA 22903'}

# %%
agent_executor.invoke(
    prompt.format(
        query = "What is the median rent price by zip code?"
    )
)
# Out:
# > Entering new SQL Agent Executor chain...
#  I need to find the median rent price for each zip code, so I will need to use the current_market_stats table and group by zip code.
# Action: sql_db_query
# Action Input: SELECT zipCode, median(averageRent) FROM current_market_stats GROUP BY zipCode[(22901, 1944.0), (22902, 1991.0), (22903, 2463.5), (22911, 2376.0), (22923, 2475.0), (22932, 2600.0), (22936, 1725.0), (22940, 2650.0), (22942, 1462.0), (22947, 3100.0), (22968, 2169.0), (24590, 1562.5)] I need to double check my query before executing it.
# Action: sql_db_query_checker
# Action Input: SELECT zipCode, median(averageRent) FROM current_market_stats GROUP BY zipCode
# SELECT zipCode, median(averageRent) FROM current_market_stats WHERE averageRent IS NOT NULL GROUP BY zipCode I now know the final answer.
# Final Answer: The median rent price by zip code is [(22901, 1944.0), (22902, 1991.0), (22903, 2463.5), (22911, 2376.0), (22923, 2475.0), (22932, 2600.0), (22936, 1725.0), (22940, 2650.0), (22942, 1462.0), (22947, 3100.0), (22968, 2169.0), (24590, 1562.5)].
#
# > Finished chain.
# {'input': "/\nYou are a SQL analyst that is querying a database of real estate data. The database has the following tables:\n\n1. **counties**: Stores the identifiers and names of counties.\n   - `id`: Unique identifier for each county.\n   - `county`: Name of the county.\n\n2. **current_market_stats**: Contains current rental market statistics by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Average rental price.\n   - `minRent`: Minimum rental price.\n   - `maxRent`: Maximum rental price.\n   - `totalListings`: Total number of rental listings.\n   - `lastUpdatedDate`: Date when the data was last updated.\n   - `zipCode`: Zip code of the rental property.\n\n3. **historic_market_stats**: Holds historical rental market data collected over time by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Historical average rental price.\n   - `minRent`: Historical minimum rental price.\n   - `maxRent`: Historical maximum rental price.\n   - `totalListings`: Historical number of rental listings.\n   - `date`: Date of the recorded data.\n   - `zipCode`: Zip code of the rental property.\n\n4. **long_term_rentals**: Details long-term rental listings.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the listing.\n   - `price`: Rental price.\n   - `status`: Current status of the listing.\n   - `daysOnMarket`: Number of days the property has been on the market.\n   - `listedDate`, `createdDate`, `lastSeenDate`, `removedDate`: Relevant dates regarding the property's listing status.\n\n5. **properties**: General information about properties.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the record.\n   - `formattedAddress`: Full address of the property.\n   - `zipCode`: Zip code of the property.\n   - `county`: County where the property is located.\n   - `subdivision`: Subdivision of the property.\n   - `latitude`, `longitude`: Geographical coordinates of the property.\n   - `propertyType`: Type of the property (e.g., residential, commercial).\n   - `ownerOccupied`: Indicates if the property is owner-occupied.\n   - `yearBuilt`: Year the property was built.\n   - `lastSaleDate`, `lastSalePrice`: Most recent sale date and price.\n   - `zoning`: Zoning classification of the property.\n   - `assessorID`, `legalDescription`: Assessor's identification and legal description of the property.\n\n6. **property_features**: Specific features of properties.\n   - `property_id`: Unique identifier for the property.\n   - `bedrooms`, `bathrooms`: Number of bedrooms and bathrooms.\n   - `squareFootage`: Total square footage of the property.\n   - `lotSize`: Size of the property's lot.\n   - `floorCount`: Number of floors in the property.\n   - `garage`, `garageType`: Indicates if there is a garage and its type.\n   - `architectureType`, `exteriorType`: Architectural and exterior material type.\n   - `heating`, `heatingType`, `cooling`, `coolingType`: Heating and cooling systems and their types.\n   - `unitCount`, `garageSpaces`: Number of units and garage spaces.\n   - `roofType`, `foundationType`: Type of roof and foundation.\n   - `roomCount`: Number of rooms.\n   - `fireplace`, `fireplaceType`: Indicates presence of a fireplace and its type.\n   - `pool`, `poolType`, `viewType`: Presence of a pool, its type, and view type.\n\n7. **property_owners**: Information about property owners.\n   - `owner_id`: Unique identifier for the owner.\n   - `property_id`: Unique identifier for the property.\n   - `owner`: Name of the property owner.\n\n8. **property_taxes**: Property tax records.\n   - `property_tax_id`: Unique identifier for the tax record.\n   - `property_id`: Unique identifier for the property.\n   - `year`: Tax year.\n   - `total`: Total amount of property tax.\n\n9. **property_types**: Descriptions of different property types.\n   - `id`: Unique identifier for the property type.\n   - `propertyType`: Type of property.\n   - `de ...
#  'output': 'The median rent price by zip code is [(22901, 1944.0), (22902, 1991.0), (22903, 2463.5), (22911, 2376.0), (22923, 2475.0), (22932, 2600.0), (22936, 1725.0), (22940, 2650.0), (22942, 1462.0), (22947, 3100.0), (22968, 2169.0), (24590, 1562.5)].'}

# %%
agent_executor.invoke(
    prompt.format(
        query = "What is the address and square footage of the largest property?"
    )
)
# Out:
# > Entering new SQL Agent Executor chain...
#  I need to find the largest property in terms of square footage, so I will need to use the property_features table to get the square footage and the properties table to get the address.
# Action: sql_db_query
# Action Input: SELECT formattedAddress, squareFootage FROM properties INNER JOIN property_features ON properties.property_id = property_features.property_id ORDER BY squareFootage DESC LIMIT 1[('1540 Avemore Ln, Charlottesville, VA 22911', 336000.0)]I need to make sure my query is correct before executing it.
# Action: sql_db_query_checker
# Action Input: SELECT formattedAddress, squareFootage FROM properties INNER JOIN property_features ON properties.property_id = property_features.property_id ORDER BY squareFootage DESC LIMIT 1
# SELECT formattedAddress, squareFootage
# FROM properties
# INNER JOIN property_features
# ON properties.property_id = property_features.property_id
# WHERE squareFootage IS NOT NULL
# ORDER BY squareFootage DESC
# LIMIT 1; I should also check the schema of the tables I am using to make sure I am using the correct fields.
# Action: sql_db_schema
# Action Input: properties, property_features
# CREATE TABLE properties (
# 	property_id VARCHAR,
# 	id VARCHAR,
# 	"formattedAddress" VARCHAR,
# 	"zipCode" INTEGER,
# 	county VARCHAR,
# 	subdivision VARCHAR,
# 	latitude REAL,
# 	longitude REAL,
# 	"propertyType" VARCHAR,
# 	"ownerOccupied" INTEGER,
# 	"yearBuilt" REAL,
# 	"lastSaleDate" VARCHAR,
# 	"lastSalePrice" REAL,
# 	zoning VARCHAR,
# 	"assessorID" VARCHAR,
# 	"legalDescription" VARCHAR
# )
#
# /*
# 3 rows from properties table:
# property_id	id	formattedAddress	zipCode	county	subdivision	latitude	longitude	propertyType	ownerOccupied	yearBuilt	lastSaleDate	lastSalePrice	zoning	assessorID	legalDescription
# c6b549be-e4e4-56db-8a92-1d7f12fb7172	4580-Lambeth,-Charlottesville,-VA-22904	4580 Lambeth, Charlottesville, VA 22904	22904	Albemarle	None	38.04106140136719	-78.50210571289062	None	None	None	None	None	None	None	None
# 37f12acf-ee26-5199-960f-f910b90b4d08	4545-Lambeth,-Charlottesville,-VA-22904	4545 Lambeth, Charlottesville, VA 22904	22904	Albemarle	None	38.04106140136719	-78.50210571289062	None	None	None	None	None	None	None	None
# f124568d-8218-5724-9031-35d34b0fe49a	4501-Lambeth,-Charlottesville,-VA-22904	4501 Lambeth, Charlottesville, VA 22904	22904	Albemarle	None	38.04106140136719	-78.50210571289062	None	None	None	None	None	None	None	None
# */
#
#
# CREATE TABLE property_features (
# 	property_id VARCHAR,
# 	bedrooms REAL,
# 	bathrooms REAL,
# 	"squareFootage" REAL,
# 	"lotSize" REAL,
# 	"floorCount" REAL,
# 	garage INTEGER,
# 	"garageType" VARCHAR,
# 	"architectureType" VARCHAR,
# 	"exteriorType" VARCHAR,
# 	heating INTEGER,
# 	"heatingType" VARCHAR,
# 	cooling INTEGER,
# 	"coolingType" VARCHAR,
# 	"unitCount" REAL,
# 	"garageSpaces" REAL,
# 	"roofType" VARCHAR,
# 	"foundationType" VARCHAR,
# 	"roomCount" REAL,
# 	fireplace INTEGER,
# 	"fireplaceType" VARCHAR,
# 	pool INTEGER,
# 	"poolType" VARCHAR,
# 	"viewType" VARCHAR
# )
#
# /*
# 3 rows from property_features table:
# property_id	bedrooms	bathrooms	squareFootage	lotSize	floorCount	garage	garageType	architectureType	exteriorType	heating	heatingType	cooling	coolingType	unitCount	garageSpaces	roofType	foundationType	roomCount	fireplace	fireplaceType	pool	poolType	viewType
# 0002939e-49d9-5578-b0fd-2bdac3057bae	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# 00075623-f6c9-54ba-a326-367830d9d027	None	1.0	722.0	None	2.0	None	None	Townhouse	Brick	1	Heat Pump	1	Central	1.0	None	Composition Shingle	None	6.0	1	Prefab	None	None	None
# 00098105-7a85-5d19-9dc5-630ba94b6a4f	3.0	4.0	4228.0	206474.0	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# */ I now know the final answer.
# Final Answer: The address and square footage of the largest property is 1540 Avemore Ln, Charlottesville, VA 22911 with a square footage of 336000.0.
#
# > Finished chain.
# {'input': "/\nYou are a SQL analyst that is querying a database of real estate data. The database has the following tables:\n\n1. **counties**: Stores the identifiers and names of counties.\n   - `id`: Unique identifier for each county.\n   - `county`: Name of the county.\n\n2. **current_market_stats**: Contains current rental market statistics by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Average rental price.\n   - `minRent`: Minimum rental price.\n   - `maxRent`: Maximum rental price.\n   - `totalListings`: Total number of rental listings.\n   - `lastUpdatedDate`: Date when the data was last updated.\n   - `zipCode`: Zip code of the rental property.\n\n3. **historic_market_stats**: Holds historical rental market data collected over time by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Historical average rental price.\n   - `minRent`: Historical minimum rental price.\n   - `maxRent`: Historical maximum rental price.\n   - `totalListings`: Historical number of rental listings.\n   - `date`: Date of the recorded data.\n   - `zipCode`: Zip code of the rental property.\n\n4. **long_term_rentals**: Details long-term rental listings.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the listing.\n   - `price`: Rental price.\n   - `status`: Current status of the listing.\n   - `daysOnMarket`: Number of days the property has been on the market.\n   - `listedDate`, `createdDate`, `lastSeenDate`, `removedDate`: Relevant dates regarding the property's listing status.\n\n5. **properties**: General information about properties.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the record.\n   - `formattedAddress`: Full address of the property.\n   - `zipCode`: Zip code of the property.\n   - `county`: County where the property is located.\n   - `subdivision`: Subdivision of the property.\n   - `latitude`, `longitude`: Geographical coordinates of the property.\n   - `propertyType`: Type of the property (e.g., residential, commercial).\n   - `ownerOccupied`: Indicates if the property is owner-occupied.\n   - `yearBuilt`: Year the property was built.\n   - `lastSaleDate`, `lastSalePrice`: Most recent sale date and price.\n   - `zoning`: Zoning classification of the property.\n   - `assessorID`, `legalDescription`: Assessor's identification and legal description of the property.\n\n6. **property_features**: Specific features of properties.\n   - `property_id`: Unique identifier for the property.\n   - `bedrooms`, `bathrooms`: Number of bedrooms and bathrooms.\n   - `squareFootage`: Total square footage of the property.\n   - `lotSize`: Size of the property's lot.\n   - `floorCount`: Number of floors in the property.\n   - `garage`, `garageType`: Indicates if there is a garage and its type.\n   - `architectureType`, `exteriorType`: Architectural and exterior material type.\n   - `heating`, `heatingType`, `cooling`, `coolingType`: Heating and cooling systems and their types.\n   - `unitCount`, `garageSpaces`: Number of units and garage spaces.\n   - `roofType`, `foundationType`: Type of roof and foundation.\n   - `roomCount`: Number of rooms.\n   - `fireplace`, `fireplaceType`: Indicates presence of a fireplace and its type.\n   - `pool`, `poolType`, `viewType`: Presence of a pool, its type, and view type.\n\n7. **property_owners**: Information about property owners.\n   - `owner_id`: Unique identifier for the owner.\n   - `property_id`: Unique identifier for the property.\n   - `owner`: Name of the property owner.\n\n8. **property_taxes**: Property tax records.\n   - `property_tax_id`: Unique identifier for the tax record.\n   - `property_id`: Unique identifier for the property.\n   - `year`: Tax year.\n   - `total`: Total amount of property tax.\n\n9. **property_types**: Descriptions of different property types.\n   - `id`: Unique identifier for the property type.\n   - `propertyType`: Type of property.\n   - `de ...
#  'output': 'The address and square footage of the largest property is 1540 Avemore Ln, Charlottesville, VA 22911 with a square footage of 336000.0.'}

# %% [markdown]
# ### Test Module

# %%
from rentradar.llm.agent import RentRadarLLMAgent

uri = 'duckdb:///../rentradar/db/rentradar.db'

agent = RentRadarLLMAgent(db_uri=uri)

agent.execute_query(query="What is the address of the property that paid the most property taxes in 2023?")
# Out:
# /home/timboslice/.cache/pypoetry/virtualenvs/rentradar-ZiKOXBpo-py3.10/lib/python3.10/site-packages/duckdb_engine/__init__.py:181: DuckDBEngineWarning: duckdb-engine doesn't yet support reflection on indices
#   warnings.warn(
# > Entering new SQL Agent Executor chain...
#  I need to find the property with the highest property tax payment in 2023.
# Action: sql_db_query
# Action Input: SELECT formattedAddress FROM properties
#             JOIN property_taxes ON properties.property_id = property_taxes.property_id
#             WHERE year = 2023
#             ORDER BY total DESC
#             LIMIT 1[('1215 Silverbell Ter, Charlottesville, VA 22903',)]1215 Silverbell Ter, Charlottesville, VA 22903 is the address of the property with the highest property tax payment in 2023.
# Final Answer: 1215 Silverbell Ter, Charlottesville, VA 22903
#
# > Finished chain.
# {'input': "/\nYou are a SQL analyst that is querying a database of real estate data. The database has the following tables:\n\n1. **counties**: Stores the identifiers and names of counties.\n   - `id`: Unique identifier for each county.\n   - `county`: Name of the county.\n\n2. **current_market_stats**: Contains current rental market statistics by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Average rental price.\n   - `minRent`: Minimum rental price.\n   - `maxRent`: Maximum rental price.\n   - `totalListings`: Total number of rental listings.\n   - `lastUpdatedDate`: Date when the data was last updated.\n   - `zipCode`: Zip code of the rental property.\n\n3. **historic_market_stats**: Holds historical rental market data collected over time by zip code.\n   - `bedrooms`: Number of bedrooms.\n   - `averageRent`: Historical average rental price.\n   - `minRent`: Historical minimum rental price.\n   - `maxRent`: Historical maximum rental price.\n   - `totalListings`: Historical number of rental listings.\n   - `date`: Date of the recorded data.\n   - `zipCode`: Zip code of the rental property.\n\n4. **long_term_rentals**: Details long-term rental listings.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the listing.\n   - `price`: Rental price.\n   - `status`: Current status of the listing.\n   - `daysOnMarket`: Number of days the property has been on the market.\n   - `listedDate`, `createdDate`, `lastSeenDate`, `removedDate`: Relevant dates regarding the property's listing status.\n\n5. **properties**: General information about properties.\n   - `property_id`: Unique identifier for the property.\n   - `id`: Unique identifier for the record.\n   - `formattedAddress`: Full address of the property.\n   - `zipCode`: Zip code of the property.\n   - `county`: County where the property is located.\n   - `subdivision`: Subdivision of the property.\n   - `latitude`, `longitude`: Geographical coordinates of the property.\n   - `propertyType`: Type of the property (e.g., residential, commercial).\n   - `ownerOccupied`: Indicates if the property is owner-occupied.\n   - `yearBuilt`: Year the property was built.\n   - `lastSaleDate`, `lastSalePrice`: Most recent sale date and price.\n   - `zoning`: Zoning classification of the property.\n   - `assessorID`, `legalDescription`: Assessor's identification and legal description of the property.\n\n6. **property_features**: Specific features of properties.\n   - `property_id`: Unique identifier for the property.\n   - `bedrooms`, `bathrooms`: Number of bedrooms and bathrooms.\n   - `squareFootage`: Total square footage of the property.\n   - `lotSize`: Size of the property's lot.\n   - `floorCount`: Number of floors in the property.\n   - `garage`, `garageType`: Indicates if there is a garage and its type.\n   - `architectureType`, `exteriorType`: Architectural and exterior material type.\n   - `heating`, `heatingType`, `cooling`, `coolingType`: Heating and cooling systems and their types.\n   - `unitCount`, `garageSpaces`: Number of units and garage spaces.\n   - `roofType`, `foundationType`: Type of roof and foundation.\n   - `roomCount`: Number of rooms.\n   - `fireplace`, `fireplaceType`: Indicates presence of a fireplace and its type.\n   - `pool`, `poolType`, `viewType`: Presence of a pool, its type, and view type.\n\n7. **property_owners**: Information about property owners.\n   - `owner_id`: Unique identifier for the owner.\n   - `property_id`: Unique identifier for the property.\n   - `owner`: Name of the property owner.\n\n8. **property_taxes**: Property tax records.\n   - `property_tax_id`: Unique identifier for the tax record.\n   - `property_id`: Unique identifier for the property.\n   - `year`: Tax year.\n   - `total`: Total amount of property tax.\n\n9. **property_types**: Descriptions of different property types.\n   - `id`: Unique identifier for the property type.\n   - `propertyType`: Type of property.\n   - `de ...
#  'output': '1215 Silverbell Ter, Charlottesville, VA 22903'}
